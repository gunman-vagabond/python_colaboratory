# %% [markdown]
# <a href="https://colab.research.google.com/github/gunman-vagabond/python_colaboratory/blob/master/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#import numpy as np
import matplotlib
import matplotlib.pyplot as plt

values1 = [1,3,4,8,1,5,2,2,8,5]
values2 = [5,2,5,1,2,4,2,1,3,4]

df = pd.DataFrame({'values1': values1, 'values2': values2})

df.plot()
